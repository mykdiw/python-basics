# %% [markdown]
# <center> <img src ="https://i.postimg.cc/1X8H7YYt/BITS-Logo.png" width = "400" alt="BITS Pilani Logo" /> </center>

# %% [markdown]
# <font color='green'> <h1> <center> Seaborn Tutorial 3 - Plotting with categorical data </center> </h1> </font>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.__version__
sns.set(style="ticks", color_codes=True)

# %%
#https://seaborn.pydata.org/tutorial.html

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Plotting with categorical data

# %%
#Categorical scatterplots:

#stripplot() (with kind="strip"; the default)
#swarmplot() (with kind="swarm")

#Categorical distribution plots:

#boxplot() (with kind="box")
#violinplot() (with kind="violin")
#boxenplot() (with kind="boxen")

#Categorical estimate plots:

#pointplot() (with kind="point")
#barplot() (with kind="bar")
#countplot() (with kind="count")

# %% [markdown]
# # Categorical scatterplots

# %%
sns.catplot(x="sex", y="tip", data=tips);

# %%
sns.catplot(x="sex", y="tip", jitter=False, data=tips);

# %%
sns.catplot(x="sex", y="tip", kind="swarm", data=tips);

# %%
sns.catplot(x="sex", y="tip", hue="day", kind="swarm", data=tips);

# %%
sns.catplot(x="sex", y="tip", kind="swarm", data=tips.query("time != 'Dinner'"));

# %% [markdown]
# # Categorical distribution plots

# %%
sns.catplot(x="sex", y="total_bill", kind="box", data=tips);

# %%
sns.catplot(x="sex", y="total_bill", hue="time", kind="box", data=tips);

# %%
sns.catplot(x="sex", y="total_bill", hue="time", kind="violin", data=tips);

# %%
g = sns.catplot(x="sex", y="total_bill", kind="violin", inner=None, data=tips)
sns.swarmplot(x="sex", y="total_bill", color="k", size=3, data=tips, ax=g.ax);

# %% [markdown]
# # Categorical estimate plots

# %%
sns.catplot(x="sex", y="total_bill", hue="time", kind="bar", data=tips);

# %%
sns.catplot(x="sex", y="total_bill", hue="time", kind="point", data=tips);

# %%
sns.catplot(x="sex", y="total_bill", hue="smoker",
            palette={"Yes": "g", "No": "m"},
            markers=["^", "o"], linestyles=["-", "--"],
            kind="point", data=tips);
